# %%
# Pandas - Data manipulation and analysis library
import pandas as pd
# NumPy - mathematical functions on multi-dimensional arrays and matrices
import numpy as np

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head(10)
# Out:
#    deviceid  avg_time_charging_lag1  avg_time_charging_lag2  \
# 0     28647                    5.12                   41.11
# 1     36175                   36.60                    5.16
# 2     16107                    5.51                    5.04
# 3     27362                    4.66                   39.85
# 4     19463                    5.10                   43.24
# 5     30054                   27.74                    5.12
# 6     26431                    4.67                    5.32
# 7      5491                   11.49                    7.10
# 8     43953                   35.88                   46.05
# 9     45081                    4.80                   41.35
#
#    avg_time_charging_lag3  avg_time_charging_lag7  charging_rate_lag3  \
# 0                    6.56                   25.39            0.086667
# 1                    6.23                    6.96            0.136667
# 2                    4.52                    5.96           -0.460000
# ...

# %%
df_train.describe()
# Out:
#            deviceid  avg_time_charging_lag1  avg_time_charging_lag2  \
# count  40500.000000            40500.000000            40500.000000
# mean   27511.156593               16.274839               16.521473
# std    12992.647611               15.374342               15.425769
# min     5000.000000                1.510000                1.060000
# 25%    16234.750000                4.910000                4.920000
# 50%    27528.000000                5.770000                5.830000
# 75%    38785.250000               30.100000               30.730000
# max    49999.000000               82.550000               98.890000
#
#        avg_time_charging_lag3  avg_time_charging_lag7  charging_rate_lag3  \
# count            40500.000000            40434.000000        40500.000000
# mean                16.277490               16.355088           -0.043389
# std                 15.305041               15.137390            0.776305
# ...

# %%
df_train.shape
# Out:
# (40500, 55)

# %%
df_test.shape
# Out:
# (4500, 54)

# %%
df_train.isnull().sum()
# Out:
# deviceid                          0
# avg_time_charging_lag1            0
# avg_time_charging_lag2            0
# avg_time_charging_lag3            0
# avg_time_charging_lag7           66
# charging_rate_lag3                0
# charging_rate_lag7               12
# avg_time_discharging_lag1         0
# avg_time_discharging_lag2         0
# avg_time_discharging_lag3         0
# avg_time_discharging_lag7        66
# discharging_rate_lag3             0
# discharging_rate_lag7            12
# fail_7                            0
# charge_cycle_time_below_12        0
# avg_time_charging_lag4            0
# avg_time_discharging_lag4         0
# avg_time_charging_lag5            7
# avg_time_discharging_lag5         7
# avg_time_charging_lag6           28
# avg_time_discharging_lag6        28
# avg_time_charging_lag8          162
# avg_time_discharging_lag8       162
# avg_time_charging_lag9          374
# avg_time_discharging_lag9       374
# avg_time_charging_lag10         797
# ...

# %%
df_test.isnull().sum()
# Out:
# deviceid                         0
# avg_time_charging_lag1           0
# avg_time_charging_lag2           0
# avg_time_charging_lag3           0
# avg_time_charging_lag7           3
# charging_rate_lag3               0
# charging_rate_lag7               1
# avg_time_discharging_lag1        0
# avg_time_discharging_lag2        0
# avg_time_discharging_lag3        0
# avg_time_discharging_lag7        3
# discharging_rate_lag3            0
# discharging_rate_lag7            1
# charge_cycle_time_below_12       0
# avg_time_charging_lag4           0
# avg_time_discharging_lag4        0
# avg_time_charging_lag5           1
# avg_time_discharging_lag5        1
# avg_time_charging_lag6           2
# avg_time_discharging_lag6        2
# avg_time_charging_lag8          17
# avg_time_discharging_lag8       17
# avg_time_charging_lag9          43
# avg_time_discharging_lag9       43
# avg_time_charging_lag10        103
# avg_time_discharging_lag10     103
# avg_time_charging_lag11        182
# ...

# %%
df_train['avg_time_charging_lag7']=df_train['avg_time_charging_lag7'].fillna(df_train['avg_time_charging_lag7'].mean())
df_train['charging_rate_lag7']=df_train['charging_rate_lag7'].fillna(df_train['charging_rate_lag7'].mean())
df_train['avg_time_discharging_lag7']=df_train['avg_time_discharging_lag7'].fillna(df_train['avg_time_discharging_lag7'].mean())
df_train['discharging_rate_lag7']=df_train['discharging_rate_lag7'].fillna(df_train['discharging_rate_lag7'].mean())
df_train['avg_time_charging_lag5']=df_train['avg_time_charging_lag5'].fillna(df_train['avg_time_charging_lag5'].mean())
df_train['avg_time_discharging_lag5']=df_train['avg_time_discharging_lag5'].fillna(df_train['avg_time_discharging_lag5'].mean())
df_train['avg_time_charging_lag6']=df_train['avg_time_charging_lag6'].fillna(df_train['avg_time_charging_lag6'].mean())
df_train['avg_time_discharging_lag6']=df_train['avg_time_discharging_lag6'].fillna(df_train['avg_time_discharging_lag6'].mean())
df_train['avg_time_charging_lag8']=df_train['avg_time_charging_lag8'].fillna(df_train['avg_time_charging_lag8'].mean())
df_train['avg_time_discharging_lag8']=df_train['avg_time_discharging_lag8'].fillna(df_train['avg_time_discharging_lag8'].mean())
df_train['avg_time_charging_lag9']=df_train['avg_time_charging_lag9'].fillna(df_train['avg_time_charging_lag9'].mean())
df_train['avg_time_discharging_lag9']=df_train['avg_time_discharging_lag9'].fillna(df_train['avg_time_discharging_lag9'].mean())
df_train['avg_time_charging_lag10']=df_train['avg_time_charging_lag10'].fillna(df_train['avg_time_charging_lag10'].mean())
df_train['avg_time_discharging_lag10']=df_train['avg_time_discharging_lag10'].fillna(df_train['avg_time_discharging_lag10'].mean())
df_train['avg_time_charging_lag11']=df_train['avg_time_charging_lag11'].fillna(df_train['avg_time_charging_lag11'].mean())
df_train['avg_time_discharging_lag11']=df_train['avg_time_discharging_lag11'].fillna(df_train['avg_time_discharging_lag11'].mean())
df_train['avg_time_charging_lag12']=df_train['avg_time_charging_lag12'].fillna(df_train['avg_time_charging_lag12'].mean())
df_train['avg_time_discharging_lag12']=df_train['avg_time_discharging_lag12'].fillna(df_train['avg_time_discharging_lag12'].mean())
df_train['avg_time_charging_lag13']=df_train['avg_time_charging_lag13'].fillna(df_train['avg_time_charging_lag13'].mean())
df_train['avg_time_discharging_lag13']=df_train['avg_time_discharging_lag13'].fillna(df_train['avg_time_discharging_lag13'].mean())
df_train['avg_time_charging_lag14']=df_train['avg_time_charging_lag14'].fillna(df_train['avg_time_charging_lag14'].mean())
df_train['avg_time_discharging_lag14']=df_train['avg_time_discharging_lag14'].fillna(df_train['avg_time_discharging_lag14'].mean())
df_train['discharging_rate_lag6']=df_train['discharging_rate_lag6'].fillna(df_train['discharging_rate_lag6'].mean())
df_train['discharging_rate_lag8']=df_train['discharging_rate_lag8'].fillna(df_train['discharging_rate_lag8'].mean())
df_train['charging_rate_lag6']=df_train['charging_rate_lag6'].fillna(df_train['charging_rate_lag6'].mean())

# %%
df_test['avg_time_charging_lag7']=df_test['avg_time_charging_lag7'].fillna(df_test['avg_time_charging_lag7'].mean())
df_test['charging_rate_lag7']=df_test['charging_rate_lag7'].fillna(df_test['charging_rate_lag7'].mean())
df_test['avg_time_discharging_lag7']=df_test['avg_time_discharging_lag7'].fillna(df_test['avg_time_discharging_lag7'].mean())
df_test['discharging_rate_lag7']=df_test['discharging_rate_lag7'].fillna(df_test['discharging_rate_lag7'].mean())
df_test['avg_time_charging_lag5']=df_test['avg_time_charging_lag5'].fillna(df_test['avg_time_charging_lag5'].mean())
df_test['avg_time_discharging_lag5']=df_test['avg_time_discharging_lag5'].fillna(df_test['avg_time_discharging_lag5'].mean())
df_test['avg_time_charging_lag6']=df_test['avg_time_charging_lag6'].fillna(df_test['avg_time_charging_lag6'].mean())
df_test['avg_time_discharging_lag6']=df_test['avg_time_discharging_lag6'].fillna(df_test['avg_time_discharging_lag6'].mean())
df_test['avg_time_charging_lag8']=df_test['avg_time_charging_lag8'].fillna(df_test['avg_time_charging_lag8'].mean())
df_test['avg_time_discharging_lag8']=df_test['avg_time_discharging_lag8'].fillna(df_test['avg_time_discharging_lag8'].mean())
df_test['avg_time_charging_lag9']=df_test['avg_time_charging_lag9'].fillna(df_test['avg_time_charging_lag9'].mean())
df_test['avg_time_discharging_lag9']=df_test['avg_time_discharging_lag9'].fillna(df_test['avg_time_discharging_lag9'].mean())
df_test['avg_time_charging_lag10']=df_test['avg_time_charging_lag10'].fillna(df_test['avg_time_charging_lag10'].mean())
df_test['avg_time_discharging_lag10']=df_test['avg_time_discharging_lag10'].fillna(df_test['avg_time_discharging_lag10'].mean())
df_test['avg_time_charging_lag11']=df_test['avg_time_charging_lag11'].fillna(df_test['avg_time_charging_lag11'].mean())
df_test['avg_time_discharging_lag11']=df_test['avg_time_discharging_lag11'].fillna(df_test['avg_time_discharging_lag11'].mean())
df_test['avg_time_charging_lag12']=df_test['avg_time_charging_lag12'].fillna(df_test['avg_time_charging_lag12'].mean())
df_test['avg_time_discharging_lag12']=df_test['avg_time_discharging_lag12'].fillna(df_test['avg_time_discharging_lag12'].mean())
df_test['avg_time_charging_lag13']=df_test['avg_time_charging_lag13'].fillna(df_test['avg_time_charging_lag13'].mean())
df_test['avg_time_discharging_lag13']=df_test['avg_time_discharging_lag13'].fillna(df_test['avg_time_discharging_lag13'].mean())
df_test['avg_time_charging_lag14']=df_test['avg_time_charging_lag14'].fillna(df_test['avg_time_charging_lag14'].mean())
df_test['avg_time_discharging_lag14']=df_test['avg_time_discharging_lag14'].fillna(df_test['avg_time_discharging_lag14'].mean())
df_test['discharging_rate_lag8']=df_test['discharging_rate_lag8'].fillna(df_test['discharging_rate_lag8'].mean())

# %%
print(df_train['avg_time_charging_lag7'].mean())
print(df_train['avg_time_charging_lag7'].median())
print('=================')
print(df_train['charging_rate_lag7'].mean())
print(df_train['charging_rate_lag7'].median())
# Out:
# 16.35508829203153
# 5.79
# ...
# -0.05301719027976211
# -0.003333333

# %%
print(df_train.isna().sum())
# Out:
# deviceid                       0
# avg_time_charging_lag1         0
# avg_time_charging_lag2         0
# avg_time_charging_lag3         0
# avg_time_charging_lag7         0
# charging_rate_lag3             0
# charging_rate_lag7             0
# avg_time_discharging_lag1      0
# avg_time_discharging_lag2      0
# avg_time_discharging_lag3      0
# avg_time_discharging_lag7      0
# discharging_rate_lag3          0
# discharging_rate_lag7          0
# fail_7                         0
# charge_cycle_time_below_12     0
# avg_time_charging_lag4         0
# avg_time_discharging_lag4      0
# avg_time_charging_lag5         0
# avg_time_discharging_lag5      0
# avg_time_charging_lag6         0
# avg_time_discharging_lag6      0
# avg_time_charging_lag8         0
# avg_time_discharging_lag8      0
# avg_time_charging_lag9         0
# avg_time_discharging_lag9      0
# avg_time_charging_lag10        0
# avg_time_discharging_lag10     0
# avg_time_charging_lag11        0
# ...

# %%
print(df_test.isna().sum())
# Out:
# deviceid                       0
# avg_time_charging_lag1         0
# avg_time_charging_lag2         0
# avg_time_charging_lag3         0
# avg_time_charging_lag7         0
# charging_rate_lag3             0
# charging_rate_lag7             0
# avg_time_discharging_lag1      0
# avg_time_discharging_lag2      0
# avg_time_discharging_lag3      0
# avg_time_discharging_lag7      0
# discharging_rate_lag3          0
# discharging_rate_lag7          0
# charge_cycle_time_below_12     0
# avg_time_charging_lag4         0
# avg_time_discharging_lag4      0
# avg_time_charging_lag5         0
# avg_time_discharging_lag5      0
# avg_time_charging_lag6         0
# avg_time_discharging_lag6      0
# avg_time_charging_lag8         0
# avg_time_discharging_lag8      0
# avg_time_charging_lag9         0
# avg_time_discharging_lag9      0
# avg_time_charging_lag10        0
# avg_time_discharging_lag10     0
# avg_time_charging_lag11        0
# avg_time_discharging_lag11     0
# ...

# %%
df_train.head(10)
# Out:
#    deviceid  avg_time_charging_lag1  avg_time_charging_lag2  \
# 0     28647                    5.12                   41.11
# 1     36175                   36.60                    5.16
# 2     16107                    5.51                    5.04
# 3     27362                    4.66                   39.85
# 4     19463                    5.10                   43.24
# 5     30054                   27.74                    5.12
# 6     26431                    4.67                    5.32
# 7      5491                   11.49                    7.10
# 8     43953                   35.88                   46.05
# 9     45081                    4.80                   41.35
#
#    avg_time_charging_lag3  avg_time_charging_lag7  charging_rate_lag3  \
# 0                    6.56               25.390000            0.086667
# 1                    6.23                6.960000            0.136667
# 2                    4.52                5.960000           -0.460000
# ...
